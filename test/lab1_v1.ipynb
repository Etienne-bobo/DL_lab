# %% [markdown]
# Students:
#
# - ...
# - ...
# - ...
#
# # Practical classes
#
#
# All exercices will be in Python. It is important that you keep track of exercices and structure you code correctly (e.g. create funcions that you can re-use later)
#
# We will use Jupyter notebooks (formerly known as IPython). You can read the following courses for help:
# * Python and numpy: http://cs231n.github.io/python-numpy-tutorial/
# * Jupyter / IPython : http://cs231n.github.io/ipython-tutorial/
#
#
# # Neural network: first experiments with a linear model
#
# In this first lab exercise we will code a neural network using numpy, without a neural network library.
# Next week, the lab exercise will be to extend this program with hidden layers and activation functions.
#
# The task is digit recognition: the neural network has to predict which digit in $\{0...9\}$ is written in the input picture. We will use the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset, a standard benchmark in machine learning.
#
# The model is a simple linear  classifier $o = \operatorname{softmax}(Wx + b)$ where:
# * $x$ is an input image that is represented as a column vector, each value being the "color" of a pixel
# * $W$ and $b$ are the parameters of the classifier
# * $\operatorname{softmax}$ transforms the output weight (logits) into probabilities
# * $o$ is column vector that contains the probability of each category
#
# We will train this model via stochastic gradient descent by minimizing the negative log-likelihood of the data:
# $$
#     \hat{W}, \hat{b} = \operatorname{argmin}_{W, b} \sum_{x, y} - \log p(y | x)
# $$
# Although this is a linear model, it classifies raw data without any manual feature extraction step.

# %%
# import libs that we will use
import os
import numpy as np
import matplotlib.pyplot as plt
import math

# To load the data we will use the script of Gaetan Marceau Caron
# You can download it from the course webiste and move it to the same directory that contains this ipynb file
import dataset_loader

# %matplotlib inline

# %% [markdown]
# # 1. Data

# %%
# Download mnist dataset 
# if("mnist.pkl.gz" not in os.listdir(".")):
    # this link doesn't work any more,
    # seach on google for the file "mnist.pkl.gz"
    # and download it
    # https://github.com/MichalDanielDobrzanski/DeepLearningPython/blob/master/mnist.pkl.gz

# if you have it somewhere else, you can comment the lines above
# and overwrite the path below
mnist_path = "./mnist.pkl.gz"

# %%
# load the 3 splits
train_data, dev_data, test_data = dataset_loader.load_mnist(mnist_path)

# %% [markdown]
# Each dataset is a list with two elemets:
# * data[0] contains images
# * data[1] contains labels
#
# Data is stored as numpy.ndarray. You can use data[0][i] to retrieve image number i and data[1][i] to retrieve its label.

# %%
print(type(train_data))
print(type(train_data[0]))
print(type(train_data[1]))
print(type(train_data[0][0]))
print(type(train_data[1][0]))
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.int64'>

# %%
index = 900
label = train_data[1][index]
picture = train_data[0][index]

print("label: %i" % label)
plt.imshow(picture.reshape(28,28), cmap='Greys')
# Out:
# label: 7

# %% [markdown]
# **Question:** What are the characteristics of training data? (number of samples, dimension of input, number of labels)
#
# The documentation of ndarray class is available here: https://docs.scipy.org/doc/numpy/reference/generated/numpy.ndarray.html

# %%
def getDimDataset(data):
    n_training = data[0].shape[0]
    n_feature = data[0].shape[1]
    n_label = len(set(data[1][i] for i in range(len(data[1]))))
    return n_training, n_feature, n_label

# %%
getDimDataset(train_data)
# Out:
# (50000, 784, 10)

# %% [markdown]
# # 1. Building functions
#
# We now need to build functions that are required for the neural network.
# $$
#     o = \operatorname{softmax}(Wx + b) \\
#     L(x, y) = -\log p(y | x) = -\log o[y]
# $$
#
# Note that in numpy, operator @ is used for matrix multiplication while * is used for element-wise multiplication.
# The documentation for linear algebra in numpy is available here: https://docs.scipy.org/doc/numpy/reference/routines.linalg.html
#
# The first operation is the affine transformation $v = Wx + b$.
# To compute the gradient, it is often convenient to write the forward pass as $v[i] = b[i] + \sum_j W[i, j] x[j]$.

# %%
# Input:
# - W: projection matrix
# - b: bias
# - x: input features
# Output:
# - vector
def affine_transform(W, b, x):
    v= W.dot(x) + b
    return v

# Input:
# - W: projection matrix
# - b: bias
# - x: input features
# - g: incoming gradient
# Output:
# - g_W: gradient wrt W
# - g_b: gradient wrt b
def backward_affine_transform(W, b, x, g):
    g_W = np.outer(g, x)
    g_b = g
    return g_W, g_b

# %% [markdown]
# The next cell is a (too simple) test of affine_transform and backward_affine_transform.
# It should run without error if your implementation is correct.

# %%
W = np.asarray([[ 0.63024213,  0.53679375, -0.92079597],
 [-0.1155045,   0.62780356, -0.67961305],
 [ 0.08465286, -0.06561815, -0.39778322],
 [ 0.8242268,   0.58907262, -0.52208052],
 [-0.43894227, -0.56993247,  0.09520727]])
b = np.asarray([ 0.42706842,  0.69636598, -0.85611933, -0.08682553,  0.83160079])
x = np.asarray([-0.32809223, -0.54751413,  0.81949319])

o_gold = np.asarray([-0.82819732, -0.16640748, -1.17394705, -1.10761496,  1.36568213])
g = np.asarray([-0.08938868,  0.44083873, -0.2260743,  -0.96196726, -0.53428805])
g_W_gold = np.asarray([[ 0.02932773,  0.04894156, -0.07325341],
 [-0.14463576, -0.24136543,  0.36126434],
 [ 0.07417322,  0.12377887, -0.18526635],
 [ 0.31561399,  0.52669067, -0.78832562],
 [ 0.17529576,  0.29253025, -0.43784542]])
g_b_gold = np.asarray([-0.08938868,  0.44083873, -0.2260743,  -0.96196726, -0.53428805])


# quick test of the forward pass
o = affine_transform(W, b, x)
if o.shape != o_gold.shape:
    raise RuntimeError("Unexpected output dimension: got %s, expected %s" % (str(o.shape), str(o_gold.shape)))
if not np.allclose(o, o_gold):
    raise RuntimeError("Output of the affine_transform function is incorrect")
    
# quick test if the backward pass
g_W, g_b = backward_affine_transform(W, b, x, g)
if g_W.shape != g_W_gold.shape:
        raise RuntimeError("Unexpected gradient dimension for W: got %s, expected %s" % (str(g_W.shape), str(g_W_gold.shape)))
if g_b.shape != g_b_gold.shape:
        raise RuntimeError("Unexpected gradient dimension for b: got %s, expected %s" % (str(g_b.shape), str(g_b_gold.shape)))
if not np.allclose(g_W, g_W_gold):
    raise RuntimeError("Gradient of W is incorrect")
if not np.allclose(g_b, g_b_gold):
    raise RuntimeError("Gradient of b is incorrect")

# %% [markdown]
# The softmax function:
# $$
#      o = \operatorname{softmax}(w)
# $$
# where $w$ is a vector of logits in $\mathbb R$ and $o$ a vector of probabilities such that:
# $$
#     o[i] = \frac{\exp(w[i])}{\sum_j \exp(w[j])}
# $$
# We do not need to implement the backward for this experiment.

# %%
# Input:
# - x: vector of logits
# Output
# - vector of probabilities
def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum()

# %% [markdown]
# **WARNING:** is your implementation numerically stable?
#
# The $\exp$ function results in computations that overflows (i.e. results in numbers that cannot be represented with floating point numbers).
# Therefore, it is always convenient to use the following trick to improve stability: https://timvieira.github.io/blog/post/2014/02/11/exp-normalize-trick/

# %%
# Example for testing the numerical stability of softmax
# It should return [1., 0. ,0.], not [nan, 0., 0.]
z = [1000000,1,100]
print(softmax(z))
# Out:
# [1. 0. 0.]

# %% [markdown]
# **Question**: from the result of the cell above, what can you say about the softmax output, even when it is stable?

# %%
# Just too simple test for the softmax function
x = np.asarray([0.92424884, -0.92381088, -0.74666024, -0.87705478, -0.54797015])
y_gold = np.asarray([0.57467369, 0.09053556, 0.10808233, 0.09486917, 0.13183925])

y = softmax(x)
if not np.allclose(y, y_gold):
    raise RuntimeError("Output of the softmax function is incorrect")

# %% [markdown]
# Finally, we build the loss function and its gradient for training the network.
#
# The loss function is the negative log-likelihood defined as:
# $$
#     \mathcal L(x, gold) = -\log \frac{\exp(x[gold])}{\sum_j \exp(x[j])} = -x[gold] + \log \sum_j \exp(x[j])
# $$
# This function is also called the cross-entropy loss (in Pytorch, different names are used dependending if the inputs are probabilities or raw logits).
#
# Similarly to the softmax, we have to rely on the log-sum-exp trick to stabilize the computation: https://timvieira.github.io/blog/post/2014/02/11/exp-normalize-trick/

# %%
# Input:
# - x: vector of logits
# - gold: index of the gold class
# Output:
# - scalare equal to -log(softmax(x)[gold])
def nll(x, gold):
    return -np.log(softmax(x)[gold])

# Input:
# - x: vector of logits
# - gold: index of the gold class
# - gradient (scalar)
# Output:
# - gradient wrt x
def backward_nll(x, gold, g):
    g_x = softmax(x)
    y = np.zeros(x.shape)
    y[gold] = -1
    g_x = g_x + y
    g_x = g * g_x
    return g_x

# %%
# test
x = np.asarray([-0.13590009, -0.83649656,  0.03130881,  0.42559402,  0.08488182])
y_gold = 1.5695014420179738
g_gold = np.asarray([ 0.17609875,  0.08739591, -0.79185107,  0.30875221,  0.2196042 ])

y = nll(x, 2)
g = backward_nll(x, 2, 1.)

if not np.allclose(y, y_gold):
    raise RuntimeError("Output is incorrect")

if g.shape != g_gold.shape:
        raise RuntimeError("Unexpected gradient dimension: got %s, expected %s" % (str(g.shape), str(g_gold.shape)))
if not np.allclose(g, g_gold):
    raise RuntimeError("Gradient is incorrect")

# %% [markdown]
# The following code test the implementation of the gradient using finite-difference approximation, see: https://timvieira.github.io/blog/post/2017/04/21/how-to-test-gradient-implementations/
#
# Your implementation should pass this test.

# %%
# this is python re-implementation of the test from the Dynet library
# https://github.com/clab/dynet/blob/master/dynet/grad-check.cc

def is_almost_equal(grad, computed_grad):
    #print(grad, computed_grad)
    f = abs(grad - computed_grad)
    m = max(abs(grad), abs(computed_grad))

    if f > 0.01 and m > 0.:
        f /= m

    if f > 0.01 or math.isnan(f):
        return False
    else:
        return True

def check_gradient(function, weights, true_grad, alpha = 1e-3):
    # because input can be of any dimension,
    # we build a view of the underlying data with the .shape(-1) method
    # then we can access any element of the tensor as a elements of a list
    # with a single dimension
    weights_view = weights.reshape(-1)
    true_grad_view = true_grad.reshape(-1)
    for i in range(weights_view.shape[0]):
        old = weights_view[i]

        weights_view[i] = old - alpha
        value_left = function(weights).reshape(-1)

        weights_view[i] = old + alpha
        value_right = function(weights).reshape(-1)

        weights_view[i] = old
        grad = (value_right - value_left) / (2. * alpha)

        if not is_almost_equal(grad, true_grad_view[i]):
            return False

        return True

# %%
# Test the affine transformation

x = np.random.uniform(-1, 1, (5,))
W = np.random.uniform(-1, 1, (3, 5))
b = np.random.uniform(-1, 1, (3,))

for i in range(3):
    y = affine_transform(W, b, x)
    g = np.zeros_like(y)
    g[i] = 1.
    g_W, _ = backward_affine_transform(W, b, x, g)
    print(check_gradient(lambda W: affine_transform(W, b, x)[i], W, g_W))
# Out:
# True
# True
# True

# %%
# test the negative likelihood loss

x = np.random.uniform(-1, 1, (5,))

for gold in range(5):
    y = nll(x, gold)
    g_y = backward_nll(x, gold, 1.)

    print(check_gradient(lambda x: nll(x, gold), x, g_y))
# Out:
# True
# True
# True
# True
# True

# %% [markdown]
# # 2. Parameter initialization
#
# We are now going to build the function that will be used to initialize the parameters of the neural network before training.
# Note that for parameter initialization you must use **in-place** operations:

# %%
# create a random ndarray
a = np.random.uniform(-1, 1, (5,))

# this does not change the data of the ndarray created above!
# it creates a new ndarray and replace the reference stored in a
a = np.zeros((5, ))

# this will change the underlying data of the ndarray that a points to
a[:] = 0

# similarly, this creates a new array and change the object pointed by a
a = a + 1

# while this change the underlying data of a
a += 1

# %% [markdown]
# For an affine transformation, it is common to:
# * initialize the bias to 0
# * initialize the projection matrix with Glorot initialization (also known as Xavier initialization)
#
# The formula for Glorot initialization can be found in equation 16 (page 5) of the original paper: http://proceedings.mlr.press/v9/glorot10a/glorot10a.pdf

# %%
def zero_init(b):
    b[:] = 0.

def glorot_init(W):
    n_in, n_out = W.shape
    range = np.sqrt(6 / (n_in + n_out))
    W[:] = np.random.uniform(low=-range, high=range, size=(n_in, n_out))

# %% [markdown]
# # 3. Building and training the neural network
#
# In our simple example, creating the neural network is simply instantiating the parameters $W$ and $b$.
# They must be ndarray object with the correct dimensions.

# %%
def create_parameters(dim_input, dim_output):
    W = np.zeros((dim_output, dim_input))
    b = np.zeros((dim_output,))
    
    return W, b

# %% [markdown]
# The recent success of deep learning is (partly) due to the ability to train very big neural networks.
# However, researchers became interested in building small neural networks to improve computational efficiency and memory usage.
# Therefore, we often want to compare neural networks by their number of parameters, i.e. the size of the memory required to store the parameters.

# %%
def print_n_parameters(W, b):
    n = n = W.size + b.size
    print("Number of parameters: %i" % (n))

# %% [markdown]
# We can now create the neural network and print its number of parameters:

# %%
dim_input = train_data[0].shape[1]
dim_output = len(set(train_data[1]))
W, b = create_parameters(dim_input, dim_output)
print_n_parameters(W, b)
# Out:
# Number of parameters: 7850

# %% [markdown]
# Finally, the training loop!
#
# The training loop should be structured as follows:
# * we do **epochs** over the data, i.e. one epoch is one loop over the dataset
# * at each epoch, we first loop over the data and update the network parameters with respect to the loss gradient
# * at the end of each epoch, we evaluate the network on the dev dataset
# * after all epochs are done, we evaluate our network on the test dataset and compare its performance with the performance on dev
#
# During training, it is useful to print the following information:
# * the mean loss over the epoch: it should be decreasing!
# * the accuracy on the dev set: it should be increasing!
# * the accuracy on the train set: it shoud be increasing!
#
# If you observe a decreasing loss (+increasing accuracy on test data) but decreasing accuracy on dev data, your network is overfitting!
#
# Once you have build **and tested** this a simple training loop, you should introduce the following improvements:
# * instead of evaluating on dev after each loop on the training data, you can also evaluate on dev n times per epoch
# * shuffle the data before each epoch
# * instead of memorizing the parameters of the last epoch only, you should have a copy of the parameters that produced the best value on dev data during training and evaluate on test with those instead of the parameters after the last epoch
# * learning rate decay: if you do not observe improvement on dev, you can try to reduce the step size
#
# After you conducted (successful?) experiments, you should write a report with results.

# %%
n_epochs = 100  # number of epochs
step = 0.01  # step size for gradient updates
n = 5
best_dev_accuracy = 0.0
best_params = (W.copy(), b.copy())
n_training = train_data[0].shape[0]
n_dev = dev_data[0].shape[0]
n_test = test_data[0].shape[0]

for epoch in range(n_epochs):
    # shuffle the data before each epoch
    indices = np.random.permutation(n_training)
    train_data_shuffled = (train_data[0][indices], train_data[1][indices])

    # train the model on the training data
    train_loss = 0.0
    train_correct = 0
    for x, y in zip(train_data_shuffled[0], train_data_shuffled[1]):
        # forward pass
        y_hat = affine_transform(W, b, x)
        loss = nll(y_hat, y)
        train_loss += loss

        # backward pass
        g_y_hat = backward_nll(y_hat, y, 1.)
        g_W, g_b = backward_affine_transform(W, b, x, g_y_hat)

        # gradient update
        W -= step * g_W
        b -= step * g_b

        # compute accuracy on train set
        train_correct += int(np.argmax(y_hat) == y)

    train_accuracy = train_correct / n_training
    train_loss /= n_training
    
    # print progress
    print("Epoch %d: train_loss=%.4f, train_accuracy=%.4f" %
          (epoch+1, train_loss, train_accuracy))

    # evaluate the model on the dev data
    for i in range (n):
        dev_correct = 0
        for x, y in zip(dev_data[0], dev_data[1]):
            y_hat = affine_transform(W, b, x)
            dev_correct += int(np.argmax(y_hat) == y)

        dev_accuracy = dev_correct / n_dev

        # check if dev accuracy has improved and update best parameters
        if dev_accuracy > best_dev_accuracy:
            best_dev_accuracy = dev_accuracy
            best_params = (W.copy(), b.copy())
        
        print("dev_accuracy=%.4f" %(dev_accuracy))

# evaluate the model on the test data with the best parameters
W_best, b_best = best_params
test_correct = 0
for x, y in zip(test_data[0], test_data[1]):
    y_hat = affine_transform(W_best, b_best, x)
    test_correct += int(np.argmax(y_hat) == y)

test_accuracy = test_correct / n_test

print("Best parameters: dev_accuracy=%.4f, test_accuracy=%.4f" % (best_dev_accuracy, test_accuracy))
# Out:
# Epoch 1: train_loss=0.2538, train_accuracy=0.9290
# dev_accuracy=0.9238
# dev_accuracy=0.9238
# dev_accuracy=0.9238
# dev_accuracy=0.9238
# dev_accuracy=0.9238
# Epoch 2: train_loss=0.2534, train_accuracy=0.9285
# dev_accuracy=0.9215
# dev_accuracy=0.9215
# dev_accuracy=0.9215
# dev_accuracy=0.9215
# dev_accuracy=0.9215
# Epoch 3: train_loss=0.2533, train_accuracy=0.9291
# dev_accuracy=0.9211
# dev_accuracy=0.9211
# dev_accuracy=0.9211
# dev_accuracy=0.9211
# dev_accuracy=0.9211
# Epoch 4: train_loss=0.2540, train_accuracy=0.9287
# dev_accuracy=0.9239
# dev_accuracy=0.9239
# dev_accuracy=0.9239
# dev_accuracy=0.9239
# dev_accuracy=0.9239
# Epoch 5: train_loss=0.2533, train_accuracy=0.9280
# dev_accuracy=0.9206
# dev_accuracy=0.9206
# dev_accuracy=0.9206
# dev_accuracy=0.9206
# dev_accuracy=0.9206
# Epoch 6: train_loss=0.2534, train_accuracy=0.9278
# dev_accuracy=0.9249
# dev_accuracy=0.9249
# dev_accuracy=0.9249
# dev_accuracy=0.9249
# dev_accuracy=0.9249
# Epoch 7: train_loss=0.2521, train_accuracy=0.9288
# dev_accuracy=0.9251
# dev_accuracy=0.9251
# dev_accuracy=0.9251
# dev_accuracy=0.9251
# dev_accuracy=0.9251
# Epoch 8: train_loss=0.2521, train_accuracy=0.9289
# dev_accuracy=0.9261
# dev_accuracy=0.9261
# dev_accuracy=0.9261
# dev_accuracy=0.9261
# dev_accuracy=0.9261
# Epoch 9: train_loss=0.2515, train_accuracy=0.9295
# dev_accuracy=0.9263
# dev_accuracy=0.9263
# dev_accuracy=0.9263
# dev_accuracy=0.9263
# dev_accuracy=0.9263
# Epoch 10: train_loss=0.2518, train_accuracy=0.9292
# dev_accuracy=0.9257
# dev_accuracy=0.9257
# dev_accuracy=0.9257
# dev_accuracy=0.9257
# dev_accuracy=0.9257
# Epoch 11: train_loss=0.2520, train_accuracy=0.9279
# dev_accuracy=0.9225
# dev_accuracy=0.9225
# dev_accuracy=0.9225
# dev_accuracy=0.9225
# dev_accuracy=0.9225
# Epoch 12: train_loss=0.2501, train_accuracy=0.9302
# dev_accuracy=0.9233
# dev_accuracy=0.9233
# dev_accuracy=0.9233
# dev_accuracy=0.9233
# dev_accuracy=0.9233
# Epoch 13: train_loss=0.2508, train_accuracy=0.9283
# dev_accuracy=0.9242
# dev_accuracy=0.9242
# dev_accuracy=0.9242
# dev_accuracy=0.9242
# dev_accuracy=0.9242
# Epoch 14: train_loss=0.2517, train_accuracy=0.9290
# dev_accuracy=0.9235
# dev_accuracy=0.9235
# dev_accuracy=0.9235
# dev_accuracy=0.9235
# dev_accuracy=0.9235
# Epoch 15: train_loss=0.2507, train_accuracy=0.9305
# dev_accuracy=0.9189
# dev_accuracy=0.9189
# dev_accuracy=0.9189
# dev_accuracy=0.9189
# dev_accuracy=0.9189
# Epoch 16: train_loss=0.2506, train_accuracy=0.9292
# dev_accuracy=0.9222
# dev_accuracy=0.9222
# dev_accuracy=0.9222
# dev_accuracy=0.9222
# dev_accuracy=0.9222
# Epoch 17: train_loss=0.2494, train_accuracy=0.9299
# dev_accuracy=0.9216
# dev_accuracy=0.9216
# dev_accuracy=0.9216
# dev_accuracy=0.9216
# dev_accuracy=0.9216
# Epoch 18: train_loss=0.2503, train_accuracy=0.9288
# dev_accuracy=0.9184
# dev_accuracy=0.9184
# dev_accuracy=0.9184
# dev_accuracy=0.9184
# dev_accuracy=0.9184
# Epoch 19: train_loss=0.2502, train_accuracy=0.9285
# dev_accuracy=0.9156
# dev_accuracy=0.9156
# dev_accuracy=0.9156
# dev_accuracy=0.9156
# dev_accuracy=0.9156
# Epoch 20: train_loss=0.2491, train_accuracy=0.9297
# dev_accuracy=0.9219
# dev_accuracy=0.9219
# dev_accuracy=0.9219
# dev_accuracy=0.9219
# dev_accuracy=0.9219
# Epoch 21: train_loss=0.2490, train_accuracy=0.9302
# dev_accuracy=0.9257
# dev_accuracy=0.9257
# dev_accuracy=0.9257
# dev_accuracy=0.9257
# dev_accuracy=0.9257
# Epoch 22: train_loss=0.2494, train_accuracy=0.9293
# dev_accuracy=0.9214
# dev_accuracy=0.9214
# dev_accuracy=0.9214
# dev_accuracy=0.9214
# dev_accuracy=0.9214
# Epoch 23: train_loss=0.2487, train_accuracy=0.9299
# dev_accuracy=0.9244
# dev_accuracy=0.9244
# dev_accuracy=0.9244
# dev_accuracy=0.9244
# dev_accuracy=0.9244
# Epoch 24: train_loss=0.2482, train_accuracy=0.9295
# dev_accuracy=0.9187
# dev_accuracy=0.9187
# dev_accuracy=0.9187
# dev_accuracy=0.9187
# dev_accuracy=0.9187
# Epoch 25: train_loss=0.2483, train_accuracy=0.9297
# dev_accuracy=0.9264
# dev_accuracy=0.9264
# dev_accuracy=0.9264
# dev_accuracy=0.9264
# dev_accuracy=0.9264
# Epoch 26: train_loss=0.2484, train_accuracy=0.9296
# dev_accuracy=0.9217
# dev_accuracy=0.9217
# dev_accuracy=0.9217
# dev_accuracy=0.9217
# dev_accuracy=0.9217
# Epoch 27: train_loss=0.2470, train_accuracy=0.9308
# dev_accuracy=0.9236
# dev_accuracy=0.9236
# dev_accuracy=0.9236
# dev_accuracy=0.9236
# dev_accuracy=0.9236
# Epoch 28: train_loss=0.2477, train_accuracy=0.9300
# dev_accuracy=0.9240
# dev_accuracy=0.9240
# dev_accuracy=0.9240
# dev_accuracy=0.9240
# dev_accuracy=0.9240
# Epoch 29: train_loss=0.2471, train_accuracy=0.9306
# dev_accuracy=0.9230
# dev_accuracy=0.9230
# dev_accuracy=0.9230
# dev_accuracy=0.9230
# dev_accuracy=0.9230
# Epoch 30: train_loss=0.2483, train_accuracy=0.9290
# dev_accuracy=0.9171
# dev_accuracy=0.9171
# dev_accuracy=0.9171
# dev_accuracy=0.9171
# dev_accuracy=0.9171
# Epoch 31: train_loss=0.2472, train_accuracy=0.9301
# dev_accuracy=0.9186
# dev_accuracy=0.9186
# dev_accuracy=0.9186
# dev_accuracy=0.9186
# dev_accuracy=0.9186
# Epoch 32: train_loss=0.2471, train_accuracy=0.9301
# dev_accuracy=0.9225
# dev_accuracy=0.9225
# dev_accuracy=0.9225
# dev_accuracy=0.9225
# dev_accuracy=0.9225
# Epoch 33: train_loss=0.2474, train_accuracy=0.9309
# dev_accuracy=0.9242
# dev_accuracy=0.9242
# dev_accuracy=0.9242
# dev_accuracy=0.9242
# dev_accuracy=0.9242
# Epoch 34: train_loss=0.2470, train_accuracy=0.9304
# dev_accuracy=0.9232
# dev_accuracy=0.9232
# dev_accuracy=0.9232
# dev_accuracy=0.9232
# dev_accuracy=0.9232
# Epoch 35: train_loss=0.2469, train_accuracy=0.9302
# dev_accuracy=0.9251
# dev_accuracy=0.9251
# dev_accuracy=0.9251
# dev_accuracy=0.9251
# dev_accuracy=0.9251
# Epoch 36: train_loss=0.2467, train_accuracy=0.9295
# dev_accuracy=0.9215
# dev_accuracy=0.9215
# dev_accuracy=0.9215
# dev_accuracy=0.9215
# dev_accuracy=0.9215
# Epoch 37: train_loss=0.2465, train_accuracy=0.9305
# dev_accuracy=0.9215
# dev_accuracy=0.9215
# dev_accuracy=0.9215
# dev_accuracy=0.9215
# dev_accuracy=0.9215
# Epoch 38: train_loss=0.2464, train_accuracy=0.9298
# dev_accuracy=0.9242
# dev_accuracy=0.9242
# dev_accuracy=0.9242
# dev_accuracy=0.9242
# dev_accuracy=0.9242
# Epoch 39: train_loss=0.2462, train_accuracy=0.9303
# dev_accuracy=0.9256
# dev_accuracy=0.9256
# dev_accuracy=0.9256
# dev_accuracy=0.9256
# dev_accuracy=0.9256
# Epoch 40: train_loss=0.2461, train_accuracy=0.9310
# dev_accuracy=0.9241
# dev_accuracy=0.9241
# dev_accuracy=0.9241
# dev_accuracy=0.9241
# dev_accuracy=0.9241
# Epoch 41: train_loss=0.2452, train_accuracy=0.9302
# dev_accuracy=0.9252
# dev_accuracy=0.9252
# dev_accuracy=0.9252
# dev_accuracy=0.9252
# dev_accuracy=0.9252
# Epoch 42: train_loss=0.2455, train_accuracy=0.9302
# dev_accuracy=0.9251
# dev_accuracy=0.9251
# dev_accuracy=0.9251
# dev_accuracy=0.9251
# dev_accuracy=0.9251
# Epoch 43: train_loss=0.2453, train_accuracy=0.9308
# dev_accuracy=0.9215
# dev_accuracy=0.9215
# dev_accuracy=0.9215
# dev_accuracy=0.9215
# dev_accuracy=0.9215
# Epoch 44: train_loss=0.2456, train_accuracy=0.9306
# dev_accuracy=0.9256
# dev_accuracy=0.9256
# dev_accuracy=0.9256
# dev_accuracy=0.9256
# dev_accuracy=0.9256
# Epoch 45: train_loss=0.2451, train_accuracy=0.9310
# dev_accuracy=0.9226
# dev_accuracy=0.9226
# dev_accuracy=0.9226
# dev_accuracy=0.9226
# dev_accuracy=0.9226
# Epoch 46: train_loss=0.2448, train_accuracy=0.9316
# dev_accuracy=0.9250
# dev_accuracy=0.9250
# dev_accuracy=0.9250
# dev_accuracy=0.9250
# dev_accuracy=0.9250
# Epoch 47: train_loss=0.2459, train_accuracy=0.9300
# dev_accuracy=0.9245
# dev_accuracy=0.9245
# dev_accuracy=0.9245
# dev_accuracy=0.9245
# dev_accuracy=0.9245
# Epoch 48: train_loss=0.2447, train_accuracy=0.9302
# dev_accuracy=0.9202
# dev_accuracy=0.9202
# dev_accuracy=0.9202
# dev_accuracy=0.9202
# dev_accuracy=0.9202
# Epoch 49: train_loss=0.2445, train_accuracy=0.9306
# dev_accuracy=0.9242
# dev_accuracy=0.9242
# dev_accuracy=0.9242
# dev_accuracy=0.9242
# dev_accuracy=0.9242
# Epoch 50: train_loss=0.2448, train_accuracy=0.9313
# dev_accuracy=0.9251
# dev_accuracy=0.9251
# dev_accuracy=0.9251
# dev_accuracy=0.9251
# dev_accuracy=0.9251
# Epoch 51: train_loss=0.2439, train_accuracy=0.9315
# dev_accuracy=0.9228
# dev_accuracy=0.9228
# dev_accuracy=0.9228
# dev_accuracy=0.9228
# dev_accuracy=0.9228
# Epoch 52: train_loss=0.2445, train_accuracy=0.9314
# dev_accuracy=0.9202
# dev_accuracy=0.9202
# dev_accuracy=0.9202
# dev_accuracy=0.9202
# dev_accuracy=0.9202
# Epoch 53: train_loss=0.2441, train_accuracy=0.9304
# dev_accuracy=0.9235
# dev_accuracy=0.9235
# dev_accuracy=0.9235
# dev_accuracy=0.9235
# dev_accuracy=0.9235
# Epoch 54: train_loss=0.2443, train_accuracy=0.9295
# dev_accuracy=0.9225
# dev_accuracy=0.9225
# dev_accuracy=0.9225
# dev_accuracy=0.9225
# dev_accuracy=0.9225
# Epoch 55: train_loss=0.2446, train_accuracy=0.9306
# dev_accuracy=0.9209
# dev_accuracy=0.9209
# dev_accuracy=0.9209
# dev_accuracy=0.9209
# dev_accuracy=0.9209
# Epoch 56: train_loss=0.2441, train_accuracy=0.9304
# dev_accuracy=0.9200
# dev_accuracy=0.9200
# dev_accuracy=0.9200
# dev_accuracy=0.9200
# dev_accuracy=0.9200
# Epoch 57: train_loss=0.2441, train_accuracy=0.9304
# dev_accuracy=0.9219
# dev_accuracy=0.9219
# dev_accuracy=0.9219
# dev_accuracy=0.9219
# dev_accuracy=0.9219
# Epoch 58: train_loss=0.2448, train_accuracy=0.9298
# dev_accuracy=0.9216
# dev_accuracy=0.9216
# dev_accuracy=0.9216
# dev_accuracy=0.9216
# dev_accuracy=0.9216
# Epoch 59: train_loss=0.2437, train_accuracy=0.9307
# dev_accuracy=0.9236
# dev_accuracy=0.9236
# dev_accuracy=0.9236
# dev_accuracy=0.9236
# dev_accuracy=0.9236
# Epoch 60: train_loss=0.2442, train_accuracy=0.9305
# dev_accuracy=0.9240
# dev_accuracy=0.9240
# dev_accuracy=0.9240
# dev_accuracy=0.9240
# dev_accuracy=0.9240
# Epoch 61: train_loss=0.2439, train_accuracy=0.9307
# dev_accuracy=0.9179
# dev_accuracy=0.9179
# dev_accuracy=0.9179
# dev_accuracy=0.9179
# dev_accuracy=0.9179
# Epoch 62: train_loss=0.2432, train_accuracy=0.9315
# dev_accuracy=0.9240
# dev_accuracy=0.9240
# dev_accuracy=0.9240
# dev_accuracy=0.9240
# dev_accuracy=0.9240
# Epoch 63: train_loss=0.2437, train_accuracy=0.9306
# dev_accuracy=0.9269
# dev_accuracy=0.9269
# dev_accuracy=0.9269
# dev_accuracy=0.9269
# dev_accuracy=0.9269
# Epoch 64: train_loss=0.2434, train_accuracy=0.9312
# dev_accuracy=0.9216
# dev_accuracy=0.9216
# dev_accuracy=0.9216
# dev_accuracy=0.9216
# dev_accuracy=0.9216
# Epoch 65: train_loss=0.2432, train_accuracy=0.9314
# dev_accuracy=0.9230
# dev_accuracy=0.9230
# dev_accuracy=0.9230
# dev_accuracy=0.9230
# dev_accuracy=0.9230
# Epoch 66: train_loss=0.2440, train_accuracy=0.9312
# dev_accuracy=0.9247
# dev_accuracy=0.9247
# dev_accuracy=0.9247
# dev_accuracy=0.9247
# dev_accuracy=0.9247
# Epoch 67: train_loss=0.2435, train_accuracy=0.9318
# dev_accuracy=0.9229
# dev_accuracy=0.9229
# dev_accuracy=0.9229
# dev_accuracy=0.9229
# dev_accuracy=0.9229
# Epoch 68: train_loss=0.2429, train_accuracy=0.9310
# dev_accuracy=0.9235
# dev_accuracy=0.9235
# dev_accuracy=0.9235
# dev_accuracy=0.9235
# dev_accuracy=0.9235
# Epoch 69: train_loss=0.2426, train_accuracy=0.9314
# dev_accuracy=0.9210
# dev_accuracy=0.9210
# dev_accuracy=0.9210
# dev_accuracy=0.9210
# dev_accuracy=0.9210
# Epoch 70: train_loss=0.2429, train_accuracy=0.9312
# dev_accuracy=0.9197
# dev_accuracy=0.9197
# dev_accuracy=0.9197
# dev_accuracy=0.9197
# dev_accuracy=0.9197
# Epoch 71: train_loss=0.2435, train_accuracy=0.9314
# dev_accuracy=0.9213
# dev_accuracy=0.9213
# dev_accuracy=0.9213
# dev_accuracy=0.9213
# dev_accuracy=0.9213
# Epoch 72: train_loss=0.2425, train_accuracy=0.9301
# dev_accuracy=0.9158
# dev_accuracy=0.9158
# dev_accuracy=0.9158
# dev_accuracy=0.9158
# dev_accuracy=0.9158
# Epoch 73: train_loss=0.2424, train_accuracy=0.9316
# dev_accuracy=0.9208
# dev_accuracy=0.9208
# dev_accuracy=0.9208
# dev_accuracy=0.9208
# dev_accuracy=0.9208
# Epoch 74: train_loss=0.2423, train_accuracy=0.9312
# dev_accuracy=0.9252
# dev_accuracy=0.9252
# dev_accuracy=0.9252
# dev_accuracy=0.9252
# dev_accuracy=0.9252
# Epoch 75: train_loss=0.2427, train_accuracy=0.9299
# dev_accuracy=0.9232
# dev_accuracy=0.9232
# dev_accuracy=0.9232
# dev_accuracy=0.9232
# dev_accuracy=0.9232
# Epoch 76: train_loss=0.2430, train_accuracy=0.9307
# dev_accuracy=0.9204
# dev_accuracy=0.9204
# dev_accuracy=0.9204
# dev_accuracy=0.9204
# dev_accuracy=0.9204
# Epoch 77: train_loss=0.2418, train_accuracy=0.9315
# dev_accuracy=0.9136
# dev_accuracy=0.9136
# dev_accuracy=0.9136
# dev_accuracy=0.9136
# dev_accuracy=0.9136
# Epoch 78: train_loss=0.2420, train_accuracy=0.9315
# dev_accuracy=0.9203
# dev_accuracy=0.9203
# dev_accuracy=0.9203
# dev_accuracy=0.9203
# dev_accuracy=0.9203
# Epoch 79: train_loss=0.2411, train_accuracy=0.9316
# dev_accuracy=0.9245
# dev_accuracy=0.9245
# dev_accuracy=0.9245
# dev_accuracy=0.9245
# dev_accuracy=0.9245
# Epoch 80: train_loss=0.2421, train_accuracy=0.9311
# dev_accuracy=0.9201
# dev_accuracy=0.9201
# dev_accuracy=0.9201
# dev_accuracy=0.9201
# dev_accuracy=0.9201
# Epoch 81: train_loss=0.2420, train_accuracy=0.9315
# dev_accuracy=0.9246
# dev_accuracy=0.9246
# dev_accuracy=0.9246
# dev_accuracy=0.9246
# dev_accuracy=0.9246
# Epoch 82: train_loss=0.2424, train_accuracy=0.9314
# dev_accuracy=0.9177
# dev_accuracy=0.9177
# dev_accuracy=0.9177
# dev_accuracy=0.9177
# dev_accuracy=0.9177
# Epoch 83: train_loss=0.2426, train_accuracy=0.9309
# dev_accuracy=0.9200
# dev_accuracy=0.9200
# dev_accuracy=0.9200
# dev_accuracy=0.9200
# dev_accuracy=0.9200
# Epoch 84: train_loss=0.2416, train_accuracy=0.9313
# dev_accuracy=0.9231
# dev_accuracy=0.9231
# dev_accuracy=0.9231
# dev_accuracy=0.9231
# dev_accuracy=0.9231
# Epoch 85: train_loss=0.2422, train_accuracy=0.9309
# dev_accuracy=0.9217
# dev_accuracy=0.9217
# dev_accuracy=0.9217
# dev_accuracy=0.9217
# dev_accuracy=0.9217
# Epoch 86: train_loss=0.2414, train_accuracy=0.9314
# dev_accuracy=0.9182
# dev_accuracy=0.9182
# dev_accuracy=0.9182
# dev_accuracy=0.9182
# dev_accuracy=0.9182
# Epoch 87: train_loss=0.2414, train_accuracy=0.9305
# dev_accuracy=0.9164
# dev_accuracy=0.9164
# dev_accuracy=0.9164
# dev_accuracy=0.9164
# dev_accuracy=0.9164
# Epoch 88: train_loss=0.2412, train_accuracy=0.9320
# dev_accuracy=0.9223
# dev_accuracy=0.9223
# dev_accuracy=0.9223
# dev_accuracy=0.9223
# dev_accuracy=0.9223
# Epoch 89: train_loss=0.2407, train_accuracy=0.9314
# dev_accuracy=0.9203
# dev_accuracy=0.9203
# dev_accuracy=0.9203
# dev_accuracy=0.9203
# dev_accuracy=0.9203
# Epoch 90: train_loss=0.2414, train_accuracy=0.9313
# dev_accuracy=0.9224
# dev_accuracy=0.9224
# dev_accuracy=0.9224
# dev_accuracy=0.9224
# dev_accuracy=0.9224
# Epoch 91: train_loss=0.2408, train_accuracy=0.9312
# dev_accuracy=0.9216
# dev_accuracy=0.9216
# dev_accuracy=0.9216
# dev_accuracy=0.9216
# dev_accuracy=0.9216
# Epoch 92: train_loss=0.2420, train_accuracy=0.9310
# dev_accuracy=0.9234
# dev_accuracy=0.9234
# dev_accuracy=0.9234
# dev_accuracy=0.9234
# dev_accuracy=0.9234
# Epoch 93: train_loss=0.2410, train_accuracy=0.9321
# dev_accuracy=0.9236
# dev_accuracy=0.9236
# dev_accuracy=0.9236
# dev_accuracy=0.9236
# dev_accuracy=0.9236
# Epoch 94: train_loss=0.2421, train_accuracy=0.9308
# dev_accuracy=0.9241
# dev_accuracy=0.9241
# dev_accuracy=0.9241
# dev_accuracy=0.9241
# dev_accuracy=0.9241
# Epoch 95: train_loss=0.2404, train_accuracy=0.9312
# dev_accuracy=0.9243
# dev_accuracy=0.9243
# dev_accuracy=0.9243
# dev_accuracy=0.9243
# dev_accuracy=0.9243
# Epoch 96: train_loss=0.2410, train_accuracy=0.9318
# dev_accuracy=0.9226
# dev_accuracy=0.9226
# dev_accuracy=0.9226
# dev_accuracy=0.9226
# dev_accuracy=0.9226
# Epoch 97: train_loss=0.2409, train_accuracy=0.9310
# dev_accuracy=0.9206
# dev_accuracy=0.9206
# dev_accuracy=0.9206
# dev_accuracy=0.9206
# dev_accuracy=0.9206
# Epoch 98: train_loss=0.2403, train_accuracy=0.9318
# dev_accuracy=0.9150
# dev_accuracy=0.9150
# dev_accuracy=0.9150
# dev_accuracy=0.9150
# dev_accuracy=0.9150
# Epoch 99: train_loss=0.2410, train_accuracy=0.9314
# dev_accuracy=0.9211
# dev_accuracy=0.9211
# dev_accuracy=0.9211
# dev_accuracy=0.9211
# dev_accuracy=0.9211
# Epoch 100: train_loss=0.2411, train_accuracy=0.9310
# dev_accuracy=0.9208
# dev_accuracy=0.9208
# dev_accuracy=0.9208
# dev_accuracy=0.9208
# dev_accuracy=0.9208
# Best parameters: dev_accuracy=0.9269, test_accuracy=0.9225
